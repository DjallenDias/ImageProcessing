# %%
import src.file_reading as file_reading

# %%
file_reading.read_file("box5x5x3.txt")
# Out:
# array([[[0.01333333, 0.01333333, 0.01333333, 0.01333333, 0.01333333],
#         [0.01333333, 0.01333333, 0.01333333, 0.01333333, 0.01333333],
#         [0.01333333, 0.01333333, 0.01333333, 0.01333333, 0.01333333],
#         [0.01333333, 0.01333333, 0.01333333, 0.01333333, 0.01333333],
#         [0.01333333, 0.01333333, 0.01333333, 0.01333333, 0.01333333]],
#
#        [[0.01333333, 0.01333333, 0.01333333, 0.01333333, 0.01333333],
#         [0.01333333, 0.01333333, 0.01333333, 0.01333333, 0.01333333],
#         [0.01333333, 0.01333333, 0.01333333, 0.01333333, 0.01333333],
#         [0.01333333, 0.01333333, 0.01333333, 0.01333333, 0.01333333],
#         [0.01333333, 0.01333333, 0.01333333, 0.01333333, 0.01333333]],
#
#        [[0.01333333, 0.01333333, 0.01333333, 0.01333333, 0.01333333],
#         [0.01333333, 0.01333333, 0.01333333, 0.01333333, 0.01333333],
#         [0.01333333, 0.01333333, 0.01333333, 0.01333333, 0.01333333],
# ...
